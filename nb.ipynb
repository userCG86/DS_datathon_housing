# %%
import pandas as pd

test = pd.read_csv("data/test.csv")
results = pd.read_csv("data/results_housing_class.csv")

# %%
results
# Out:
#         Id  Expensive
# 0     1461          0
# 1     1462          0
# 2     1463          0
# 3     1464          0
# 4     1465          0
# ...    ...        ...
# 1454  2915          0
# 1455  2916          0
# 1456  2917          0
# 1457  2918          0
# 1458  2919          0
#
# [1459 rows x 2 columns]

# %%
test.rename(columns={"Unnamed: 0": "Id"}).assign(Id = results["Id"]).to_csv("data/test.csv", index=False)

# %%
test["Id"] = results["Id"]

# %%
test.head()
# Out:
#    Unnamed: 0  LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  \
# 0           0    11622         80.0        882.0             2           0
# 1           1    14267         81.0       1329.0             3           0
# 2           2    13830         74.0        928.0             3           1
# 3           3     9978         78.0        926.0             3           1
# 4           4     5005         43.0       1280.0             2           0
#
#    PoolArea  GarageCars  WoodDeckSF  ScreenPorch  ... GarageType GarageFinish  \
# 0         0         1.0         140          120  ...     Attchd          Unf
# 1         0         1.0         393            0  ...     Attchd          Unf
# 2         0         2.0         212            0  ...     Attchd          Fin
# 3         0         2.0         360            0  ...     Attchd          Fin
# 4         0         2.0           0          144  ...     Attchd          RFn
#
# ...
